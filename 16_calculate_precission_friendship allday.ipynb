# %%
import pandas as pd
import numpy as np

# %%
friendshipdf_final = pd.read_csv('D://A_thesis/gowalla/out_random/second_idea/friendship_df_without_threshold_allday.csv')

# %%
del friendshipdf_final['Unnamed: 0']

# %%
friendshipdf_final
# Out:
#        userid                                        friend_list  \
# 0           1  [2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 61...
# 1           2  [1, 3, 4, 5, 6, 12, 12309, 25, 22554, 2735, 29...
# 2           3  [1, 2, 4, 5, 6, 12, 29, 3104, 33, 40, 2131, 10...
# 3           4  [1, 2, 3, 5, 6, 12, 24, 25, 29, 3104, 33, 5468...
# 4           5  [1, 2, 3, 4, 6, 12, 24, 25, 29, 33, 40, 46, 60...
# ...       ...                                                ...
# 2995  1292870                                    [279018, 53849]
# 2996  1531870  [40, 151, 499871, 8355, 204994, 242, 319801, 8...
# 2997  1645701  [977939, 61986, 16958, 470092, 82366, 129657, ...
# 2998  1722363                                                 []
# 2999  1832376                                     [3028, 252956]
#
#                                  fr_n5_AMPM  \
# 0                [2, 847, 3104, 3496, 2681]
# 1                   [1, 3496, 847, 3104, 5]
# 2                [33, 29, 90, 12912, 64929]
# ...

# %%
pre_rec = pd.DataFrame()

# %%
user_info = friendshipdf_final.loc[friendshipdf_final['userid'] == 1]

# %%
user_info
# Out:
#    userid                                        friend_list  \
# 0       1  [2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 61...
#
#                    fr_n5_AMPM  \
# 0  [2, 847, 3104, 3496, 2681]
#
#                                          fr_n10_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n15_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n20_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n25_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n30_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n35_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n40_AMPM  ...  \
# ...

# %%
user_info['friend_list_new'].values[0]
# Out:
# '2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 6179, 46, 60, 62, 92, 107, 114, 2163, 119, 120, 132, 149, 198, 238, 55541, 4358, 102759, 57718, 2444, 2477, 468, 25096, 16958, 57781, 578, 3516, 2681, 2698, 12954, 2722, 2819, 17183, 74572, 847, 2908, 862, 58215, 876, 4975, 2958, 62484, 3104, 21583, 3201, 3208, 3221, 25818, 6019, 1343, 7512, 3496, 24009, 13800, 13888, 108126, 3741, 1699, 26290, 7880, 7902, 1917, 12169, 6028'

# %%
friend_list_new = list(map(int,str(user_info['friend_list_new'].values[0]).split(',')))

# %%
# friend_list_new

# %%
fr_n5_AMPM_new = list(map(int,str(user_info['fr_n5_AMPM_new'].values[0]).split(',')))

# %%
eshterak_topn5_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n5_AMPM_new))

# %%
eshterak_topn5_AMPM_friendlist = list(eshterak_topn5_AMPM_friendlist)
eshterak_topn5_AMPM_friendlist
# Out:
# [3104, 2, 3496, 847, 2681]

# %%
eshterak_topn5_AMPM_friendlist = np.abs(eshterak_topn5_AMPM_friendlist)

# %%
len(eshterak_topn5_AMPM_friendlist)
# Out:
# 5

# %%
precission_n5_AMPM = len(eshterak_topn5_AMPM_friendlist) / len(fr_n5_AMPM_new)
precission_n5_AMPM
# Out:
# 1.0

# %%
recall_n5_AMPM = len(eshterak_topn5_AMPM_friendlist) / len(friend_list_new)
recall_n5_AMPM
# Out:
# 0.06666666666666667

# %%
fr_n10_AMPM_new = list(map(int,str(user_info['fr_n10_AMPM_new'].values[0]).split(',')))
fr_n15_AMPM_new = list(map(int,str(user_info['fr_n15_AMPM_new'].values[0]).split(',')))
fr_n20_AMPM_new = list(map(int,str(user_info['fr_n20_AMPM_new'].values[0]).split(',')))
fr_n25_AMPM_new = list(map(int,str(user_info['fr_n25_AMPM_new'].values[0]).split(',')))
fr_n30_AMPM_new = list(map(int,str(user_info['fr_n30_AMPM_new'].values[0]).split(',')))
fr_n35_AMPM_new = list(map(int,str(user_info['fr_n35_AMPM_new'].values[0]).split(',')))
fr_n40_AMPM_new = list(map(int,str(user_info['fr_n40_AMPM_new'].values[0]).split(',')))

# %%
eshterak_topn10_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n10_AMPM_new))

# %%
eshterak_topn10_AMPM_friendlist = list(eshterak_topn10_AMPM_friendlist)
eshterak_topn10_AMPM_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 847, 2681]

# %%
eshterak_topn10_AMPM_friendlist = np.abs(eshterak_topn10_AMPM_friendlist)

# %%
precission_n10_AMPM = len(eshterak_topn10_AMPM_friendlist) / len(fr_n10_AMPM_new)
precission_n10_AMPM
# Out:
# 0.7

# %%
recall_n10_AMPM = len(eshterak_topn10_AMPM_friendlist) / len(friend_list_new)
recall_n10_AMPM
# Out:
# 0.09333333333333334

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn15_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n15_AMPM_new))

# %%
eshterak_topn15_AMPM_friendlist = list(eshterak_topn15_AMPM_friendlist)
eshterak_topn15_AMPM_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 847, 3221, 2681]

# %%
eshterak_topn15_AMPM_friendlist = np.abs(eshterak_topn15_AMPM_friendlist)

# %%
precission_n15_AMPM = len(eshterak_topn15_AMPM_friendlist) / len(fr_n15_AMPM_new)
precission_n15_AMPM
# Out:
# 0.5333333333333333

# %%
recall_n15_AMPM = len(eshterak_topn15_AMPM_friendlist) / len(friend_list_new)
recall_n15_AMPM
# Out:
# 0.10666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn20_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n20_AMPM_new))

# %%
eshterak_topn20_AMPM_friendlist = list(eshterak_topn20_AMPM_friendlist)
eshterak_topn20_AMPM_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 847, 3221, 2681]

# %%
eshterak_topn20_AMPM_friendlist = np.abs(eshterak_topn20_AMPM_friendlist)

# %%
precission_n20_AMPM = len(eshterak_topn20_AMPM_friendlist) / len(fr_n20_AMPM_new)
precission_n20_AMPM
# Out:
# 0.4

# %%
recall_n20_AMPM = len(eshterak_topn20_AMPM_friendlist) / len(friend_list_new)
recall_n20_AMPM
# Out:
# 0.10666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn25_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n25_AMPM_new))

# %%
eshterak_topn25_AMPM_friendlist = list(eshterak_topn25_AMPM_friendlist)
eshterak_topn25_AMPM_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 847, 3221, 2681, 2908]

# %%
eshterak_topn25_AMPM_friendlist = np.abs(eshterak_topn25_AMPM_friendlist)

# %%
precission_n25_AMPM = len(eshterak_topn25_AMPM_friendlist) / len(fr_n25_AMPM_new)
precission_n25_AMPM
# Out:
# 0.36

# %%
recall_n25_AMPM = len(eshterak_topn25_AMPM_friendlist) / len(friend_list_new)
recall_n25_AMPM
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn30_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n30_AMPM_new))

# %%
eshterak_topn30_AMPM_friendlist = list(eshterak_topn30_AMPM_friendlist)
eshterak_topn30_AMPM_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681, 2908]

# %%
eshterak_topn30_AMPM_friendlist = np.abs(eshterak_topn30_AMPM_friendlist)

# %%
precission_n30_AMPM = len(eshterak_topn30_AMPM_friendlist) / len(fr_n30_AMPM_new)
precission_n30_AMPM
# Out:
# 0.3333333333333333

# %%
recall_n30_AMPM = len(eshterak_topn30_AMPM_friendlist) / len(friend_list_new)
recall_n30_AMPM
# Out:
# 0.13333333333333333

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn35_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n35_AMPM_new))

# %%
eshterak_topn35_AMPM_friendlist = list(eshterak_topn35_AMPM_friendlist)
eshterak_topn35_AMPM_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 12, 2477, 847, 3221, 2681, 2908]

# %%
eshterak_topn35_AMPM_friendlist = np.abs(eshterak_topn35_AMPM_friendlist)

# %%
precission_n35_AMPM = len(eshterak_topn35_AMPM_friendlist) / len(fr_n35_AMPM_new)
precission_n35_AMPM
# Out:
# 0.3142857142857143

# %%
recall_n35_AMPM = len(eshterak_topn35_AMPM_friendlist) / len(friend_list_new)
recall_n35_AMPM
# Out:
# 0.14666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn40_AMPM_friendlist = set(friend_list_new).intersection(set(fr_n40_AMPM_new))

# %%
eshterak_topn40_AMPM_friendlist = list(eshterak_topn40_AMPM_friendlist)
eshterak_topn40_AMPM_friendlist
# Out:
# [3104, 2, 6019, 578, 5, 3496, 12, 2477, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn40_AMPM_friendlist = np.abs(eshterak_topn40_AMPM_friendlist)

# %%
precission_n40_AMPM = len(eshterak_topn40_AMPM_friendlist) / len(fr_n40_AMPM_new)
precission_n40_AMPM
# Out:
# 0.35

# %%
recall_n40_AMPM = len(eshterak_topn40_AMPM_friendlist) / len(friend_list_new)
recall_n40_AMPM
# Out:
# 0.18666666666666668

# %%
user_info = pd.read_csv('D://A_thesis/gowalla/out_random/second_idea/precission_recall_allday.csv')

# %%
user_info
# Out:
#    Unnamed: 0  userid                                        friend_list  \
# 0         0.0     1.0  [2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 61...
# 1         NaN     NaN                                                NaN
# 2         NaN     NaN                                                NaN
# 3         NaN     NaN                                                NaN
# 4         NaN     NaN                                                NaN
# 5         NaN     NaN                                                NaN
# 6         NaN     NaN                                                NaN
# 7         NaN     NaN                                                NaN
#
#                    fr_n5_AMPM  \
# 0  [2, 847, 3104, 3496, 2681]
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
#
# ...

# %%
user_info['precission_n5_AMPM'] = precission_n5_AMPM
user_info['precission_n10_AMPM'] = precission_n10_AMPM
user_info['precission_n15_AMPM'] = precission_n15_AMPM
user_info['precission_n20_AMPM'] = precission_n20_AMPM
user_info['precission_n25_AMPM'] = precission_n25_AMPM
user_info['precission_n30_AMPM'] = precission_n30_AMPM
user_info['precission_n35_AMPM'] = precission_n35_AMPM
user_info['precission_n40_AMPM'] = precission_n40_AMPM
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-49537d4ed4fd> in <module>
# ----> 1 user_info['precission_n5_AMPM'] = precission_n5_AMPM
#       2 user_info['precission_n10_AMPM'] = precission_n10_AMPM
#       3 user_info['precission_n15_AMPM'] = precission_n15_AMPM
#       4 user_info['precission_n20_AMPM'] = precission_n20_AMPM
#       5 user_info['precission_n25_AMPM'] = precission_n25_AMPM
#
# NameError: name 'precission_n5_AMPM' is not defined

# %%
user_info['recall_n5_AMPM']  = recall_n5_AMPM
user_info['recall_n10_AMPM']  = recall_n10_AMPM
user_info['recall_n15_AMPM']  = recall_n15_AMPM
user_info['recall_n20_AMPM']  = recall_n20_AMPM
user_info['recall_n25_AMPM']  = recall_n25_AMPM
user_info['recall_n30_AMPM']  = recall_n30_AMPM
user_info['recall_n35_AMPM']  = recall_n35_AMPM
user_info['recall_n40_AMPM']  = recall_n40_AMPM

# %%
user_info.to_csv('D://A_thesis/gowalla/out_random/second_idea/precission_recall_allday.csv')

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
fr_n5_first_method_allday_new = list(map(int,str(user_info['fr_n5_first_method_allday_new'].values[0]).split(',')))
fr_n10_first_method_allday_new = list(map(int,str(user_info['fr_n10_first_method_allday_new'].values[0]).split(',')))
fr_n15_first_method_allday_new = list(map(int,str(user_info['fr_n15_first_method_allday_new'].values[0]).split(',')))
fr_n20_first_method_allday_new = list(map(int,str(user_info['fr_n20_first_method_allday_new'].values[0]).split(',')))
fr_n25_first_method_allday_new = list(map(int,str(user_info['fr_n25_first_method_allday_new'].values[0]).split(',')))
fr_n30_first_method_allday_new = list(map(int,str(user_info['fr_n30_first_method_allday_new'].values[0]).split(',')))
fr_n35_first_method_allday_new = list(map(int,str(user_info['fr_n35_first_method_allday_new'].values[0]).split(',')))
fr_n40_first_method_allday_new = list(map(int,str(user_info['fr_n40_first_method_allday_new'].values[0]).split(',')))

# %%
eshterak_topn5_first_method_friendlist = set(friend_list_new).intersection(set(fr_n5_first_method_allday_new))

# %%
eshterak_topn5_first_method_friendlist = list(eshterak_topn5_first_method_friendlist)
eshterak_topn5_first_method_friendlist
# Out:
# [3104, 2, 6019, 847, 2681]

# %%
eshterak_topn5_first_method_friendlist = np.abs(eshterak_topn5_first_method_friendlist)

# %%
precission_n5_first_method = len(eshterak_topn5_first_method_friendlist) / len(fr_n5_first_method_allday_new)
precission_n5_first_method
# Out:
# 1.0

# %%
recall_n5_first_method = len(eshterak_topn5_first_method_friendlist) / len(friend_list_new)
recall_n5_first_method
# Out:
# 0.06666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn10_first_method_friendlist = set(friend_list_new).intersection(set(fr_n10_first_method_allday_new))

# %%
eshterak_topn10_first_method_friendlist = list(eshterak_topn10_first_method_friendlist)
eshterak_topn10_first_method_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 847, 2681]

# %%
eshterak_topn10_first_method_friendlist = np.abs(eshterak_topn10_first_method_friendlist)

# %%
precission_n10_first_method = len(eshterak_topn10_first_method_friendlist) / len(fr_n10_first_method_allday_new)
precission_n10_first_method
# Out:
# 0.7

# %%
recall_n10_first_method = len(eshterak_topn10_first_method_friendlist) / len(friend_list_new)
recall_n10_first_method
# Out:
# 0.09333333333333334

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn15_first_method_friendlist = set(friend_list_new).intersection(set(fr_n15_first_method_allday_new))

# %%
eshterak_topn15_first_method_friendlist = list(eshterak_topn15_first_method_friendlist)
eshterak_topn15_first_method_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 847, 2681]

# %%
eshterak_topn15_first_method_friendlist = np.abs(eshterak_topn15_first_method_friendlist)

# %%
precission_n15_first_method = len(eshterak_topn15_first_method_friendlist) / len(fr_n15_first_method_allday_new)
precission_n15_first_method
# Out:
# 0.4666666666666667

# %%
recall_n15_first_method = len(eshterak_topn15_first_method_friendlist) / len(friend_list_new)
recall_n15_first_method
# Out:
# 0.09333333333333334

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn20_first_method_friendlist = set(friend_list_new).intersection(set(fr_n20_first_method_allday_new))

# %%
eshterak_topn20_first_method_friendlist = list(eshterak_topn20_first_method_friendlist)
eshterak_topn20_first_method_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681]

# %%
eshterak_topn20_first_method_friendlist = np.abs(eshterak_topn20_first_method_friendlist)

# %%
precission_n20_first_method = len(eshterak_topn20_first_method_friendlist) / len(fr_n20_first_method_allday_new)
precission_n20_first_method
# Out:
# 0.45

# %%
recall_n20_first_method = len(eshterak_topn20_first_method_friendlist) / len(friend_list_new)
recall_n20_first_method
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn25_first_method_friendlist = set(friend_list_new).intersection(set(fr_n25_first_method_allday_new))

# %%
eshterak_topn25_first_method_friendlist = list(eshterak_topn25_first_method_friendlist)
eshterak_topn25_first_method_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681]

# %%
eshterak_topn25_first_method_friendlist = np.abs(eshterak_topn25_first_method_friendlist)

# %%
precission_n25_first_method = len(eshterak_topn25_first_method_friendlist) / len(fr_n25_first_method_allday_new)
precission_n25_first_method
# Out:
# 0.36

# %%
recall_n25_first_method = len(eshterak_topn25_first_method_friendlist) / len(friend_list_new)
recall_n25_first_method
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn30_first_method_friendlist = set(friend_list_new).intersection(set(fr_n30_first_method_allday_new))

# %%
eshterak_topn30_first_method_friendlist = list(eshterak_topn30_first_method_friendlist)
eshterak_topn30_first_method_friendlist
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 57718, 2681]

# %%
eshterak_topn30_first_method_friendlist = np.abs(eshterak_topn30_first_method_friendlist)

# %%
precission_n30_first_method = len(eshterak_topn30_first_method_friendlist) / len(fr_n30_first_method_allday_new)
precission_n30_first_method
# Out:
# 0.3333333333333333

# %%
recall_n30_first_method = len(eshterak_topn30_first_method_friendlist) / len(friend_list_new)
recall_n30_first_method
# Out:
# 0.13333333333333333

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn35_first_method_friendlist = set(friend_list_new).intersection(set(fr_n35_first_method_allday_new))

# %%
eshterak_topn35_first_method_friendlist = list(eshterak_topn35_first_method_friendlist)
eshterak_topn35_first_method_friendlist
# Out:
# [3104, 2, 6019, 578, 5, 6, 3496, 12, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn35_first_method_friendlist = np.abs(eshterak_topn35_first_method_friendlist)

# %%
precission_n35_first_method = len(eshterak_topn35_first_method_friendlist) / len(fr_n35_first_method_allday_new)
precission_n35_first_method
# Out:
# 0.4

# %%
recall_n35_first_method = len(eshterak_topn35_first_method_friendlist) / len(friend_list_new)
recall_n35_first_method
# Out:
# 0.18666666666666668

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn40_first_method_friendlist = set(friend_list_new).intersection(set(fr_n40_first_method_allday_new))

# %%
eshterak_topn40_first_method_friendlist = list(eshterak_topn40_first_method_friendlist)
eshterak_topn40_first_method_friendlist
# Out:
# [3104, 2, 6019, 578, 5, 6, 3496, 12, 2477, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn40_first_method_friendlist = np.abs(eshterak_topn40_first_method_friendlist)

# %%
precission_n40_first_method = len(eshterak_topn40_first_method_friendlist) / len(fr_n40_first_method_allday_new)
precission_n40_first_method
# Out:
# 0.375

# %%
recall_n40_first_method = len(eshterak_topn40_first_method_friendlist) / len(friend_list_new)
recall_n40_first_method
# Out:
# 0.2

# %%
user_info['precission_n5_first_method'] = precission_n5_first_method
user_info['precission_n10_first_method'] = precission_n10_first_method
user_info['precission_n15_first_method'] = precission_n15_first_method
user_info['precission_n20_first_method'] = precission_n20_first_method
user_info['precission_n25_first_method'] = precission_n25_first_method
user_info['precission_n30_first_method'] = precission_n30_first_method
user_info['precission_n35_first_method'] = precission_n35_first_method
user_info['precission_n40_first_method'] = precission_n40_first_method
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
user_info['recall_n5_first_method']  = recall_n5_first_method
user_info['recall_n10_first_method']  = recall_n10_first_method
user_info['recall_n15_first_method']  = recall_n15_first_method
user_info['recall_n20_first_method']  = recall_n20_first_method
user_info['recall_n25_first_method']  = recall_n25_first_method
user_info['recall_n30_first_method']  = recall_n30_first_method
user_info['recall_n35_first_method']  = recall_n35_first_method
user_info['recall_n40_first_method']  = recall_n40_first_method
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
# user_info = user_info.drop(columns=['fr_n5', 'fr_n10' , 'fr_n15' , 'fr_n20'])

# %%
user_info
# Out:
#    userid                                        friend_list  \
# 0       1  [2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 61...
#
#                    fr_n5_AMPM  \
# 0  [2, 847, 3104, 3496, 2681]
#
#                                          fr_n10_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n15_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n20_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n25_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n30_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n35_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n40_AMPM  ...  \
# ...

# %%
# user_info.to_csv('D://A_thesis/gowalla/out_random/precission_recall.csv')

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
                                  _______________second_mode_______________

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
fr_n5_second_method_new = list(map(int,str(user_info['fr_n5_second_method_allday_new'].values[0]).split(',')))
fr_n10_second_method_new = list(map(int,str(user_info['fr_n10_second_method_allday_new'].values[0]).split(',')))
fr_n15_second_method_new = list(map(int,str(user_info['fr_n15_second_method_allday_new'].values[0]).split(',')))
fr_n20_second_method_new = list(map(int,str(user_info['fr_n20_second_method_allday_new'].values[0]).split(',')))
fr_n25_second_method_new = list(map(int,str(user_info['fr_n25_second_method_allday_new'].values[0]).split(',')))
fr_n30_second_method_new = list(map(int,str(user_info['fr_n30_second_method_allday_new'].values[0]).split(',')))
fr_n35_second_method_new = list(map(int,str(user_info['fr_n35_second_method_allday_new'].values[0]).split(',')))
fr_n40_second_method_new = list(map(int,str(user_info['fr_n40_second_method_allday_new'].values[0]).split(',')))

# %%
eshterak_topn5_friendlist_second_method = set(friend_list_new).intersection(set(fr_n5_second_method_new))

# %%
eshterak_topn5_friendlist_second_method = list(eshterak_topn5_friendlist_second_method)
eshterak_topn5_friendlist_second_method
# Out:
# [3104, 2, 6019, 847, 2681]

# %%
eshterak_topn5_friendlist_second_method = np.abs(eshterak_topn5_friendlist_second_method)

# %%
precission_n5_second_method = len(eshterak_topn5_friendlist_second_method) / len(fr_n5_second_method_new)
precission_n5_second_method
# Out:
# 1.0

# %%
recall_n5_second_method = len(eshterak_topn5_friendlist_second_method) / len(friend_list_new)
recall_n5_second_method
# Out:
# 0.06666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn10_friendlist_second_method = set(friend_list_new).intersection(set(fr_n10_second_method_new))

# %%
eshterak_topn10_friendlist_second_method = list(eshterak_topn10_friendlist_second_method)
eshterak_topn10_friendlist_second_method
# Out:
# [3104, 2, 6019, 5, 3496, 847, 2681]

# %%
eshterak_topn10_friendlist_second_method = np.abs(eshterak_topn10_friendlist_second_method)

# %%
precission_n10_second_method = len(eshterak_topn10_friendlist_second_method) / len(fr_n10_second_method_new)
precission_n10_second_method
# Out:
# 0.7

# %%
recall_n10_second_method = len(eshterak_topn10_friendlist_second_method) / len(friend_list_new)
recall_n10_second_method
# Out:
# 0.09333333333333334

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn15_friendlist_second_method = set(friend_list_new).intersection(set(fr_n15_second_method_new))

# %%
eshterak_topn15_friendlist_second_method = list(eshterak_topn15_friendlist_second_method)
eshterak_topn15_friendlist_second_method
# Out:
# [3104, 2, 6019, 5, 3496, 847, 3221, 2681]

# %%
eshterak_topn15_friendlist_second_method = np.abs(eshterak_topn15_friendlist_second_method)

# %%
precission_n15_second_method = len(eshterak_topn15_friendlist_second_method) / len(fr_n15_second_method_new)
precission_n15_second_method
# Out:
# 0.5333333333333333

# %%
recall_n15_second_method = len(eshterak_topn15_friendlist_second_method) / len(friend_list_new)
recall_n15_second_method
# Out:
# 0.10666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn20_friendlist_second_method = set(friend_list_new).intersection(set(fr_n20_second_method_new))

# %%
eshterak_topn20_friendlist_second_method = list(eshterak_topn20_friendlist_second_method)
eshterak_topn20_friendlist_second_method
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681]

# %%
eshterak_topn20_friendlist_second_method = np.abs(eshterak_topn20_friendlist_second_method)

# %%
precission_n20_second_method = len(eshterak_topn20_friendlist_second_method) / len(fr_n20_second_method_new)
precission_n20_second_method
# Out:
# 0.45

# %%
recall_n20_second_method = len(eshterak_topn20_friendlist_second_method) / len(friend_list_new)
recall_n20_second_method
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn25_friendlist_second_method = set(friend_list_new).intersection(set(fr_n25_second_method_new))

# %%
eshterak_topn25_friendlist_second_method = list(eshterak_topn25_friendlist_second_method)
eshterak_topn25_friendlist_second_method
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681]

# %%
eshterak_topn25_friendlist_second_method = np.abs(eshterak_topn25_friendlist_second_method)

# %%
precission_n25_second_method = len(eshterak_topn25_friendlist_second_method) / len(fr_n25_second_method_new)
precission_n25_second_method
# Out:
# 0.36

# %%
recall_n25_second_method = len(eshterak_topn25_friendlist_second_method) / len(friend_list_new)
recall_n25_second_method
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn30_friendlist_second_method = set(friend_list_new).intersection(set(fr_n30_second_method_new))

# %%
eshterak_topn30_friendlist_second_method = list(eshterak_topn30_friendlist_second_method)
eshterak_topn30_friendlist_second_method
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681, 2908]

# %%
eshterak_topn30_friendlist_second_method = np.abs(eshterak_topn30_friendlist_second_method)

# %%
precission_n30_second_method = len(eshterak_topn30_friendlist_second_method) / len(fr_n30_second_method_new)
precission_n30_second_method
# Out:
# 0.3333333333333333

# %%
recall_n30_second_method = len(eshterak_topn30_friendlist_second_method) / len(friend_list_new)
recall_n30_second_method
# Out:
# 0.13333333333333333

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn35_friendlist_second_method = set(friend_list_new).intersection(set(fr_n35_second_method_new))

# %%
eshterak_topn35_friendlist_second_method = list(eshterak_topn35_friendlist_second_method)
eshterak_topn35_friendlist_second_method
# Out:
# [3104, 2, 6019, 578, 5, 3496, 12, 2477, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn35_friendlist_second_method = np.abs(eshterak_topn35_friendlist_second_method)

# %%
precission_n35_second_method = len(eshterak_topn35_friendlist_second_method) / len(fr_n35_second_method_new)
precission_n35_second_method
# Out:
# 0.4

# %%
recall_n35_second_method = len(eshterak_topn35_friendlist_second_method) / len(friend_list_new)
recall_n35_second_method
# Out:
# 0.18666666666666668

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn40_friendlist_second_method = set(friend_list_new).intersection(set(fr_n40_second_method_new))

# %%
eshterak_topn40_friendlist_second_method = list(eshterak_topn40_friendlist_second_method)
eshterak_topn40_friendlist_second_method
# Out:
# [3104, 2, 6019, 578, 5, 6, 3496, 12, 2477, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn40_friendlist_second_method = np.abs(eshterak_topn40_friendlist_second_method)

# %%
precission_n40_second_method = len(eshterak_topn40_friendlist_second_method) / len(fr_n40_second_method_new)
precission_n40_second_method
# Out:
# 0.375

# %%
recall_n40_second_method = len(eshterak_topn40_friendlist_second_method) / len(friend_list_new)
recall_n40_second_method
# Out:
# 0.2

# %%
user_info['precission_n5_second_method'] = precission_n5_second_method
user_info['precission_n10_second_method'] = precission_n10_second_method
user_info['precission_n15_second_method'] = precission_n15_second_method
user_info['precission_n20_second_method'] = precission_n20_second_method
user_info['precission_n25_second_method'] = precission_n25_second_method
user_info['precission_n30_second_method'] = precission_n30_second_method
user_info['precission_n35_second_method'] = precission_n35_second_method
user_info['precission_n40_second_method'] = precission_n40_second_method
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
user_info['recall_n5_second_method']  = recall_n5_second_method
user_info['recall_n10_second_method']  = recall_n10_second_method
user_info['recall_n15_second_method']  = recall_n15_second_method
user_info['recall_n20_second_method']  = recall_n20_second_method
user_info['recall_n25_second_method'] = recall_n25_second_method
user_info['recall_n30_second_method'] = recall_n30_second_method
user_info['recall_n35_second_method'] = recall_n35_second_method
user_info['recall_n40_second_method'] = recall_n40_second_method
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
user_info
# Out:
#    userid                                        friend_list  \
# 0       1  [2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 61...
#
#                    fr_n5_AMPM  \
# 0  [2, 847, 3104, 3496, 2681]
#
#                                          fr_n10_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n15_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n20_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n25_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n30_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n35_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n40_AMPM  ...  \
# ...

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
                                  _______________third_mode_______________

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
fr_n5_third_method_new = list(map(int,str(user_info['fr_n5_third_method_allday_new'].values[0]).split(',')))
fr_n10_third_method_new = list(map(int,str(user_info['fr_n10_third_method_allday_new'].values[0]).split(',')))
fr_n15_third_method_new = list(map(int,str(user_info['fr_n15_third_method_allday_new'].values[0]).split(',')))
fr_n20_third_method_new = list(map(int,str(user_info['fr_n20_third_method_allday_new'].values[0]).split(',')))
fr_n25_third_method_new = list(map(int,str(user_info['fr_n25_third_method_allday_new'].values[0]).split(',')))
fr_n30_third_method_new = list(map(int,str(user_info['fr_n30_third_method_allday_new'].values[0]).split(',')))
fr_n35_third_method_new = list(map(int,str(user_info['fr_n35_third_method_allday_new'].values[0]).split(',')))
fr_n40_third_method_new = list(map(int,str(user_info['fr_n40_third_method_allday_new'].values[0]).split(',')))

# %%
eshterak_topn5_friendlist_third_method = set(friend_list_new).intersection(set(fr_n5_third_method_new))

# %%
eshterak_topn5_friendlist_third_method = list(eshterak_topn5_friendlist_third_method)
eshterak_topn5_friendlist_third_method
# Out:
# [3104, 2, 6019, 3496, 847]

# %%
eshterak_topn5_friendlist_third_method = np.abs(eshterak_topn5_friendlist_third_method)

# %%
precission_n5_third_method = len(eshterak_topn5_friendlist_third_method) / len(fr_n5_second_method_new)
precission_n5_third_method
# Out:
# 1.0

# %%
recall_n5_third_method = len(eshterak_topn5_friendlist_third_method) / len(friend_list_new)
recall_n5_third_method
# Out:
# 0.06666666666666667

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn10_friendlist_third_method = set(friend_list_new).intersection(set(fr_n10_third_method_new))

# %%
eshterak_topn10_friendlist_third_method = list(eshterak_topn10_friendlist_third_method)
eshterak_topn10_friendlist_third_method
# Out:
# [3104, 2, 6019, 5, 3496, 847, 2681]

# %%
eshterak_topn10_friendlist_third_method = np.abs(eshterak_topn10_friendlist_third_method)

# %%
precission_n10_third_method = len(eshterak_topn10_friendlist_third_method) / len(fr_n10_second_method_new)
precission_n10_third_method
# Out:
# 0.7

# %%
recall_n10_third_method = len(eshterak_topn10_friendlist_third_method) / len(friend_list_new)
recall_n10_third_method
# Out:
# 0.09333333333333334

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn15_friendlist_third_method = set(friend_list_new).intersection(set(fr_n15_third_method_new))

# %%
eshterak_topn15_friendlist_third_method = list(eshterak_topn15_friendlist_third_method)
eshterak_topn15_friendlist_third_method
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681]

# %%
eshterak_topn15_friendlist_third_method = np.abs(eshterak_topn15_friendlist_third_method)

# %%
precission_n15_third_method = len(eshterak_topn15_friendlist_third_method) / len(fr_n15_second_method_new)
precission_n15_third_method
# Out:
# 0.6

# %%
recall_n15_third_method = len(eshterak_topn15_friendlist_third_method) / len(friend_list_new)
recall_n15_third_method
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn20_friendlist_third_method = set(friend_list_new).intersection(set(fr_n20_third_method_new))

# %%
eshterak_topn20_friendlist_third_method = list(eshterak_topn20_friendlist_third_method)
eshterak_topn20_friendlist_third_method
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681]

# %%
eshterak_topn20_friendlist_third_method = np.abs(eshterak_topn20_friendlist_third_method)

# %%
precission_n20_third_method = len(eshterak_topn20_friendlist_third_method) / len(fr_n20_second_method_new)
precission_n20_third_method
# Out:
# 0.45

# %%
recall_n20_third_method = len(eshterak_topn20_friendlist_third_method) / len(friend_list_new)
recall_n20_third_method
# Out:
# 0.12

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn25_friendlist_third_method = set(friend_list_new).intersection(set(fr_n25_third_method_new))

# %%
eshterak_topn25_friendlist_third_method = list(eshterak_topn25_friendlist_third_method)
eshterak_topn25_friendlist_third_method
# Out:
# [3104, 2, 6019, 5, 3496, 12, 847, 3221, 2681, 2908]

# %%
eshterak_topn25_friendlist_third_method = np.abs(eshterak_topn25_friendlist_third_method)

# %%
precission_n25_third_method = len(eshterak_topn25_friendlist_third_method) / len(fr_n25_second_method_new)
precission_n25_third_method
# Out:
# 0.4

# %%
recall_n25_third_method = len(eshterak_topn25_friendlist_third_method) / len(friend_list_new)
recall_n25_third_method
# Out:
# 0.13333333333333333

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn30_friendlist_third_method = set(friend_list_new).intersection(set(fr_n30_third_method_new))

# %%
eshterak_topn30_friendlist_third_method = list(eshterak_topn30_friendlist_third_method)
eshterak_topn30_friendlist_third_method
# Out:
# [3104, 2, 6019, 578, 5, 6, 3496, 12, 847, 3221, 7512, 2681, 2908]

# %%
eshterak_topn30_friendlist_third_method = np.abs(eshterak_topn30_friendlist_third_method)

# %%
precission_n30_third_method = len(eshterak_topn30_friendlist_third_method) / len(fr_n30_second_method_new)
precission_n30_third_method
# Out:
# 0.43333333333333335

# %%
recall_n30_third_method = len(eshterak_topn30_friendlist_third_method) / len(friend_list_new)
recall_n30_third_method
# Out:
# 0.17333333333333334

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn35_friendlist_third_method = set(friend_list_new).intersection(set(fr_n35_third_method_new))

# %%
eshterak_topn35_friendlist_third_method = list(eshterak_topn35_friendlist_third_method)
eshterak_topn35_friendlist_third_method
# Out:
# [3104, 2, 6019, 578, 5, 6, 3496, 12, 2477, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn35_friendlist_third_method = np.abs(eshterak_topn35_friendlist_third_method)

# %%
precission_n35_third_method = len(eshterak_topn35_friendlist_third_method) / len(fr_n35_second_method_new)
precission_n35_third_method
# Out:
# 0.42857142857142855

# %%
recall_n35_third_method = len(eshterak_topn35_friendlist_third_method) / len(friend_list_new)
recall_n35_third_method
# Out:
# 0.2

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
eshterak_topn40_friendlist_third_method = set(friend_list_new).intersection(set(fr_n40_third_method_new))

# %%
eshterak_topn40_friendlist_third_method = list(eshterak_topn40_friendlist_third_method)
eshterak_topn40_friendlist_third_method
# Out:
# [3104, 2, 6019, 578, 5, 6, 3496, 12, 2477, 847, 3221, 57718, 7512, 2681, 2908]

# %%
eshterak_topn40_friendlist_third_method = np.abs(eshterak_topn40_friendlist_third_method)

# %%
precission_n40_third_method = len(eshterak_topn40_friendlist_third_method) / len(fr_n40_second_method_new)
precission_n40_third_method
# Out:
# 0.375

# %%
recall_n40_third_method = len(eshterak_topn40_friendlist_third_method) / len(friend_list_new)
recall_n40_third_method
# Out:
# 0.2

# %%
                                *****************************************
                                *****************************************
                                *****************************************

# %%
user_info['precission_n5_third_method'] = precission_n5_third_method
user_info['precission_n10_third_method'] = precission_n10_third_method
user_info['precission_n15_third_method'] = precission_n15_third_method
user_info['precission_n20_third_method'] = precission_n20_third_method
user_info['precission_n25_third_method'] = precission_n25_third_method
user_info['precission_n30_third_method'] = precission_n30_third_method
user_info['precission_n35_third_method'] = precission_n35_third_method
user_info['precission_n40_third_method'] = precission_n40_third_method
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
user_info['recall_n5_third_method']  = recall_n5_third_method
user_info['recall_n10_third_method']  = recall_n10_third_method
user_info['recall_n15_third_method']  = recall_n15_third_method
user_info['recall_n20_third_method']  = recall_n20_third_method
user_info['recall_n25_third_method'] = recall_n25_third_method
user_info['recall_n30_third_method'] = recall_n30_third_method
user_info['recall_n35_third_method'] = recall_n35_third_method
user_info['recall_n40_third_method'] = recall_n40_third_method
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\Lenovo\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
user_info
# Out:
#    userid                                        friend_list  \
# 0       1  [2, 3, 4, 5, 6, 12, 24, 25, 26, 28, 29, 33, 61...
#
#                    fr_n5_AMPM  \
# 0  [2, 847, 3104, 3496, 2681]
#
#                                          fr_n10_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n15_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n20_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n25_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n30_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n35_AMPM  \
# 0  [2, 847, 3104, 3496, 2681, 6019, 756, 5, 950, ...
#
#                                          fr_n40_AMPM  ...  \
# ...

# %%
user_info.to_csv('D://A_thesis/gowalla/out_random/second_idea/precission_recall_allday.csv')

# %%
                                *****************************************
                                *****************************************
                                *****************************************
